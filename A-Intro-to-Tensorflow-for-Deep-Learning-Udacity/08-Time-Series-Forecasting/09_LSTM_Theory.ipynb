# %% [markdown]
# # LSTM Cell
#
# ![21.%20LSTM.JPG](attachment:21.%20LSTM.JPG)

# %% [markdown]
# # Implementing an LSTM (using Keras)

# %% [markdown]
# ![22.%20Implementing%20LSTM.JPG](attachment:22.%20Implementing%20LSTM.JPG)
